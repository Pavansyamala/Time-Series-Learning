# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf , plot_pacf , acf , pacf

# %%
data_dict = {
    'month' : ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May' , 'Jun' , 'Jul' , 'Aug' , 'Sep' , 'Oct' , 'Nov' , 'Dec'] ,
    'Sales' : [100 , 203 , 301 , 408 , 500 , 602 , 704 , 805 , 906 , 1009 , 1107 , 1204]
}
data = pd.DataFrame(data_dict)

# %%
sns.relplot(data = data , x = 'month' , y = 'Sales' , kind = 'scatter')
plt.show()

# %%
t_1 = data['Sales'].values[:-1]

# %%
t = data['Sales'].values[1:]

# %%
new_data = t - t_1

# %%
t
# Out:
# array([ 203,  301,  408,  500,  602,  704,  805,  906, 1009, 1107, 1204])

# %%
t_1
# Out:
# array([ 100,  203,  301,  408,  500,  602,  704,  805,  906, 1009, 1107])

# %%
plt.scatter(x = [i for i in range(1,12)] , y = new_data)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
sales_ = np.random.randint(low = 100 , high = 1000 , size = (90 , 1))

# %%
add_result = seasonal_decompose(sales_ , model = 'additive' , period = 30)

# %%
add_result.plot()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(data['Sales'])

# %%
test_statistic = result[0]
p_value = result[1]

# %%
critical_value = result[4]

# %%
critical_value
# Out:
# {'1%': -4.223238279489106, '5%': -3.189368925619835, '10%': -2.729839421487603}
